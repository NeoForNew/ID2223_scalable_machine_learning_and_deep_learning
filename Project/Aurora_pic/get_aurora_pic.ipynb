# %%
import requests
import datetime
def get_pictures(url,path):
    headers={
        'user-agent': 'Mozilla/5.0 (Windows NT 10.0; WOW64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/70.0.3538.25 Safari/537.36 Core/1.70.3861.400 QQBrowser/10.7.4313.400'} 
    re=requests.get(url,headers=headers)
    print(re.status_code)#查看请求状态，返回200说明正常
    with open(path, 'wb') as f:#把图片数据写入本地，wb表示二进制储存
                for chunk in re.iter_content(chunk_size=128):
                    f.write(chunk)

# %%
start = datetime.datetime.fromisoformat('2020-12-31')
delta = datetime.timedelta(days=1)
end = start + datetime.timedelta(days=365)
endnow=str(end.strftime('%Y%m%d'))
offset=start

# %%
while str(offset.strftime('%Y%m%d')) != endnow:
    offset += delta
    date = str(offset.strftime('%Y%m%d'))
    url = 'https://www.irf.se/alis/allsky/krn/2021/'+date[4:6] +'/' + date[6:8] + '/' + 'dark_keo' + date +'.gif'
    path = './'+ date + '.gif'
    get_pictures(url, path)
    print(url)
# Out:
# 200
# https://www.irf.se/alis/allsky/krn/2021/01/01/dark_keo20210101.gif
# 200
# https://www.irf.se/alis/allsky/krn/2021/01/02/dark_keo20210102.gif
# 200
# https://www.irf.se/alis/allsky/krn/2021/01/03/dark_keo20210103.gif
# 200
# https://www.irf.se/alis/allsky/krn/2021/01/04/dark_keo20210104.gif
# 200
# https://www.irf.se/alis/allsky/krn/2021/01/05/dark_keo20210105.gif
# 200
# https://www.irf.se/alis/allsky/krn/2021/01/06/dark_keo20210106.gif
# 200
# https://www.irf.se/alis/allsky/krn/2021/01/07/dark_keo20210107.gif
# 200
# https://www.irf.se/alis/allsky/krn/2021/01/08/dark_keo20210108.gif
# 200
# https://www.irf.se/alis/allsky/krn/2021/01/09/dark_keo20210109.gif
# 200
# https://www.irf.se/alis/allsky/krn/2021/01/10/dark_keo20210110.gif
# 200
# https://www.irf.se/alis/allsky/krn/2021/01/11/dark_keo20210111.gif
# 200
# https://www.irf.se/alis/allsky/krn/2021/01/12/dark_keo20210112.gif
# 200
# https://www.irf.se/alis/allsky/krn/2021/01/13/dark_keo20210113.gif
# 200
# ...
